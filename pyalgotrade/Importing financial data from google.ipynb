# %%
import pandas as pd
import pandas.io.data as web
import numpy as np
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline

# %%
rn = np.random.standard_normal(100)
rn[:10]
# Out:
# array([ 0.58595923,  0.16477752, -2.02765795, -0.41125546,  0.91850489,
#         0.11207   , -0.14865083, -1.20821528,  0.89147636,  0.03885019])

# %%
plt.plot(rn.cumsum())
plt.grid(True)

# %%
AAPL = web.DataReader('AAPL', data_source='google')
  # reads data from Google Finance
AAPL['42d'] = pd.rolling_mean(AAPL['Close'], 42)
AAPL['252d'] = pd.rolling_mean(AAPL['Close'], 252)
  # 42d and 252d trends

# %%
AAPL[['Close', '42d', '252d']].plot(figsize=(10, 5))

# %%
aapl = web.get_data_yahoo('AAPL', 
                                 start=datetime.datetime(2012, 5, 1), 
                                 end=datetime.datetime(2015, 9, 11))
aapl.head()
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2012-05-01  584.900009  596.759987  581.230019  582.130013  152749800
# 2012-05-02  580.239983  587.399986  578.859978  585.979980  106847300
# 2012-05-03  590.499977  591.400024  580.300011  581.819992   97637400
# 2012-05-04  577.080017  578.359993  565.169998  565.250000  132498100
# 2012-05-07  561.500008  572.770012  561.229988  569.480003  115029600
#
#             Adj Close
# Date
# 2012-05-01  77.764270
# 2012-05-02  78.278571
# 2012-05-03  77.722856
# 2012-05-04  75.509341
# 2012-05-07  76.074409

# %%
aapl.tail()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2015-09-03  112.489998  112.779999  110.040001  110.370003  52906400
# 2015-09-04  108.970001  110.449997  108.510002  109.269997  49963900
# 2015-09-08  111.750000  112.559998  110.320000  112.309998  54114200
# 2015-09-09  113.760002  114.019997  109.769997  110.150002  84344400
# 2015-09-10  110.269997  113.279999  109.900002  112.570000  62675200
#
#              Adj Close
# Date
# 2015-09-03  110.370003
# 2015-09-04  109.269997
# 2015-09-08  112.309998
# 2015-09-09  110.150002
# 2015-09-10  112.570000

# %%
aapl['42d'] = pd.rolling_mean(aapl['Close'], 42)
aapl['252d'] = pd.rolling_mean(aapl['Close'], 252)
  # 42d and 252d trends
aapl[['Close', '42d', '252d']].plot(figsize=(10, 5))
